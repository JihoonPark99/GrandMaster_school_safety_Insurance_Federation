# %% [markdown]
# Colab에서 진행
# - 링크 : https://colab.research.google.com/drive/18Sk8WbNboC8W6TV5CgRkpSpjD4sfPN9g?usp=sharing

# %% [markdown]
# # Module Import

# %%
# pip install konlpy
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

# %%
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from wordcloud.wordcloud import FONT_PATH
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import numpy as np
from os import path


path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
font_name = fm.FontProperties(fname=path, size=50).get_name()
plt.rc('font', family=font_name)

# %% [markdown]
# # Data Load

# %%
data = pd.read_excel('/content/drive/MyDrive/학교안전사고대회/학교안전사고데이터셋모음/survey_for_Submit.xlsx', index_col = 0)
data.head(2)

# %% [markdown]
# ## 불용어 및 의미없는 토큰 제거

# %%
text = "".join(data['피드백'].values)
text = text.replace("좋겠어요", "")
text = text.replace("학교", "")
text = text.replace("안전한", "")
text = text.replace("학생들에게", "")
text = text.replace("학생들이", "")
text = text.replace("모든", "")
text = text.replace("잘", "")
text = text.replace("해주면", "")
text = text.replace("있도록", "")
text = text.replace("심어주면", "")
text
# Out:
# '학생 사고 예방을 위해 정기적인 안전 교육이 필요하다고 생각.저는 에서 안전 수칙을 철저히 알려주세요.안전을 위해  내 위험 구역 홍보?.사고를 줄이기 위해 교실마다 응급처치키트 배치안전 교육 실시.실습 시간에 안전 장비를 꼭 착용하도록 지도. 안전하게 활동할 수  선생님들이 항상 주의 놀이 공간이 확보해주세요에서 안전 수칙에 대한 포스터를 곳곳에 붙여주면 . 안전하게 생활을 할 수  안전 점검? 안전훈련?.선생님들이 항상 안전 수칙을 상기시켜주면 .친구들과 함께 안전 수칙을 배우는 활동이 필요하다고 생각해요. 내 안전 관련 시설을 늘렸으면 .사고가 발생했을 때 빠르게 대응할 수 있는 시스템이 필요해요.안전 교육 자료를 쉽게 접근할 수  온라인에 올려주면 . 안전 수칙을  지킬 수  상을 주는 프로그램이 있으면 .에서 안전 캠페인을 자주 열어주면 . 내 CCTV를 늘려서 사고를 예방할 수 있으면 .안전 교육 영상을 자주 보여주면 . 체육 수업을 위해 필요한 장비를 더 많이 구비 . 스스로 안전 수칙을 지키도록 동기를 부여 .사고가 발생한 사례를 공유해서 경각심을 높여주면 .교실마다 안전 수칙을 적어 놓은 게시판이 있으면 .안전 교육에 재미있는 요소를 추가해서 흥미를 끌어주면 . 안전 수칙을  이해하도록 퀴즈나 게임을 도입하면 .에서 안전 관련 동아리를 만들어서 활동할 수 있게 해주세요. 내 안전 점검 결과를 학생들과 공유하면 .사고를 예방하기 위해  내 구조를 개선했으면 .안전 교육을 위한 특별 강사를 초청하면 . 안전 수칙을  지키도록 선생님들이 항상 강조 .실습 시간에는 항상 안전 수칙을 상기시켜주세요.에서 안전 관련 책자를 배포하면 .사고를 줄이기 위해  내   안전 교육을 의무화했으면 .  생활을 위해 학기 초에 안전 교육을 집중적으로 했으면 . 내 안전 담당 선생님을 두면 .에서 정기적으로 안전 설문조사를 실시하면 .안전 수칙을  지킨  포상을 하면 .에서 안전 관련 워크숍을 개최하면 .안전 수칙을  지킬 수   책임감을  .에서  환경을 만들기
# ...

# %% [markdown]
# ## 워드클라우드 생성

# %%
FONT_PATH = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'

wordcloud = WordCloud(width=800, height=400,
                      background_color='white',
                      collocations=False,
                      font_path = FONT_PATH).generate(text)


plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
# plt.title('WordCloud using Feedback', fontsize=15)
plt.show()
